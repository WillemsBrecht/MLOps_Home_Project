# %% [markdown]
# # MLops project - Lung segmentation - 02 deployment

# %% [markdown]
# ## Imort packages

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
 
import azureml.core

# display the core SDK version number
print("Azure ML SDK Version: ", azureml.core.VERSION)
# Out:
# Azure ML SDK Version:  1.34.0

# %%
# %%writefile score.py
import json
import numpy as np
import os
import tensorflow as tf
import cv2

from azureml.core.model import Model
import onnxruntime

def init():
    global model_path
    global output_names
    model_path = Model.get_model_path(model_name='lungs_autoencoder')

def run(image):
    data = np.array(json.loads(image)['image']).astype('float32')
    print(f'data: { data }')
    session = onnxruntime.InferenceSession(model_path)
    # first_input_name = session.get_inputs()[0].name
    # first_output_name = session.get_outputs()[0].name

    result = session.run(None, {"input": data})
    print(f'result {result}     {type(result)}')
    test = json.dumps({"image": result})
    test = bytes(test, encoding='utf8')
    return test
# Out:
# Overwriting score.py

# %% [markdown]
# ### Create configuration file
#
# Create a deployment configuration file and specify the number of CPUs and gigabyte of RAM needed for your ACI container. While it depends on your model, the default of 1 core and 1 gigabyte of RAM is usually sufficient for many models. If you feel you need more later, you would have to recreate the image and redeploy the service.

# %%
from azureml.core.webservice import AciWebservice

aciconfig = AciWebservice.deploy_configuration(cpu_cores=1, 
                                               memory_gb=1, 
                                               tags={"data": "lung images",  "method" : "autoencoder"}, 
                                               description='lung segmentation autoencoder')

# %% [markdown]
# ### Deploy in ACI
# Estimated time to complete: **about 2-5 minutes**
#
# Configure the image and deploy. The following code goes through these steps:
#
# 1. Create environment object containing dependencies needed by the model using the environment file (`myenv.yml`)
# 1. Create inference configuration necessary to deploy the model as a web service using:
#    * The scoring file (`score.py`)
#    * envrionment object created in previous step
# 1. Deploy the model to the ACI container.
# 1. Get the web service HTTP endpoint.

# %%
# %%time
import uuid
from azureml.core.webservice import Webservice
from azureml.core.model import InferenceConfig
from azureml.core.environment import Environment
from azureml.core import Workspace
from azureml.core.model import Model

ws = Workspace.from_config()
model = Model(ws, 'lungs_autoencoder')


myenv = Environment.get(workspace=ws, name="lungs-env", version="1")
inference_config = InferenceConfig(entry_script="score.py", environment=myenv)

service_name = 'autoencoder-svc-' + str(uuid.uuid4())[:4]
service = Model.deploy(workspace=ws, 
                       name=service_name, 
                       models=[model], 
                       inference_config=inference_config, 
                       deployment_config=aciconfig)

service.wait_for_deployment(show_output=True)
# Out:
# Warning, custom base image or base dockerfile detected without a specified `inferencing_stack_version`. Please set environment.inferencing_stack_version='latest'
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running
# 2021-11-24 13:48:17+00:00 Creating Container Registry if not exists.
# 2021-11-24 13:48:17+00:00 Registering the environment.
# 2021-11-24 13:48:18+00:00 Use the existing image.
# 2021-11-24 13:48:19+00:00 Submitting deployment to compute.
# 2021-11-24 13:48:24+00:00 Checking the status of deployment autoencoder-svc-5821..
# 2021-11-24 13:51:59+00:00 Checking the status of inference endpoint autoencoder-svc-5821.
# Succeeded
# ACI service creation operation finished, operation "Succeeded"
# CPU times: user 806 ms, sys: 101 ms, total: 907 ms
# Wall time: 3min 50s

# %%
print(service.scoring_uri)
# Out:
# http://bc733ac9-c304-42e5-aa47-95439f8a969c.westeurope.azurecontainer.io/score

# %% [markdown]
# ## Test the model

# %% [markdown]
# ### Download test data
# Download the test data to the **./data/** directory

# %%
# azureml-core of version 1.0.72 or higher is required
from azureml.core import Workspace, Dataset

dataset_folder = os.path.join(os.getcwd(), "dataset")
os.makedirs(dataset_folder, exist_ok=True)

subscription_id = '31701647-d61e-4ee8-a1ae-e4fc5d71e6f6'
resource_group = 'MLOps-Home-Grp_8'
workspace_name = 'mlopslungs'

workspace = Workspace(subscription_id, resource_group, workspace_name)

dataset = Dataset.get_by_name(workspace, name='lung_data')
dataset.download(target_path=dataset_folder, overwrite=True)
# Out:
# ['/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0001_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0002_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0003_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0004_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0005_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0006_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0007_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0008_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0009_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0010_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0011_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0012_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0013_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0014_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0015_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0016_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0017_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0018_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0019_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0020_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0021_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0022_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0023_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0024_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0026_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0027_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0028_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0029_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0030_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0031_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0032_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0033_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0034_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0035_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0041_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0042_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0043_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0044_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0045_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0046_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0047_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0048_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0049_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0050_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0051_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0052_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0053_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0054_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0055_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0056_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0057_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0058_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0059_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0060_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0061_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0062_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0063_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0064_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0066_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0067_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0068_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0069_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0070_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0071_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0072_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0073_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0074_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0075_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0076_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0077_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0078_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0079_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0080_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0081_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0082_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0083_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0084_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0085_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0086_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0087_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0088_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0089_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0090_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0091_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0092_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0093_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0094_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0095_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0096_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0097_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0098_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0099_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0100_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0101_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0102_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0103_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0104_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0105_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0106_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0107_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0108_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0109_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0110_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0111_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0112_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0113_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0114_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0115_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0116_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0117_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0118_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0119_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0120_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0121_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0122_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0123_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0124_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0125_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0126_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0127_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0128_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0129_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0130_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0131_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0132_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0133_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0134_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0135_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0136_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0137_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0138_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0139_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0140_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0141_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0142_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0143_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0144_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0145_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0146_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0147_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0148_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0149_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0150_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0151_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0152_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0153_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0154_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0155_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0156_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0157_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0158_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0159_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0160_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0161_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0162_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0163_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0164_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0165_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0166_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0167_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0168_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0169_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0170_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0171_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0172_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0173_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0174_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0175_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0176_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0177_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0178_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0179_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0180_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0221_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0222_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0223_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0224_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0225_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0226_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0227_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0228_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0229_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0230_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0231_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0232_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0233_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0234_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0235_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0236_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0237_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0238_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0239_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0240_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0241_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0242_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0243_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0244_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0245_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0246_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0247_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0248_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0249_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0250_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0251_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0252_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0253_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0254_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0255_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0256_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0257_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0258_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0259_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0260_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0261_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0262_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0263_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0264_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0265_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0266_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0267_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0268_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0269_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0270_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0271_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0272_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0273_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_0274_0.png',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mlopslungs/code/Users/brecht.willems2/dataset/Lung_images/CHNCXR_
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
resize = cv2.resize(im_rgb, (400,400))

# normalize image
image = np.array(resize)
image = image.reshape(-1, 400, 400, 1)
image = image.astype('float32') / 255

# json dump
test = json.dumps({"image": image.tolist()})
test = bytes(test, encoding='utf8')

y_hat = service.run(test)
print(image.shape)
# Out:
# Received bad response from service. More information can be found by calling `.get_logs()` on the webservice object.
# Response Code: 502
# Headers: {'Connection': 'keep-alive', 'Content-Length': '49', 'Content-Type': 'text/html; charset=utf-8', 'Date': 'Wed, 24 Nov 2021 13:52:14 GMT', 'Server': 'nginx/1.10.3 (Ubuntu)', 'X-Ms-Request-Id': '44c6cd42-9dc1-46ce-b007-78b7d0844908', 'X-Ms-Run-Function-Failed': 'True'}
# Content: b"Object of type 'ndarray' is not JSON serializable"
# ---------------------------------------------------------------------------
# WebserviceException                       Traceback (most recent call last)
# /tmp/ipykernel_14282/3654062146.py in <module>
#      18 test = bytes(test, encoding='utf8')
#      19
# ---> 20 y_hat = service.run(test)
#      21 print(image.shape)
#
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/azureml/core/webservice/aci.py in run(self, input_data)
#     398             return resp.json()
#     399         else:
# --> 400             raise WebserviceException('Received bad response from service. More information can be found by calling '
#     401                                       '`.get_logs()` on the webservice object.\n'
#     402                                       'Response Code: {}\n'
#
# WebserviceException: WebserviceException:
# 	Message: Received bad response from service. More information can be found by calling `.get_logs()` on the webservice object.
# Response Code: 502
# Headers: {'Connection': 'keep-alive', 'Content-Length': '49', 'Content-Type': 'text/html; charset=utf-8', 'Date': 'Wed, 24 Nov 2021 13:52:14 GMT', 'Server': 'nginx/1.10.3 (Ubuntu)', 'X-Ms-Request-Id': '44c6cd42-9dc1-46ce-b007-78b7d0844908', 'X-Ms-Run-Function-Failed': 'True'}
# Content: b"Object of type 'ndarray' is not JSON serializable"
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Received bad response from service. More information can be found by calling `.get_logs()` on the webservice object.\nResponse Code: 502\nHeaders: {'Connection': 'keep-alive', 'Content-Length': '49', 'Content-Type': 'text/html; charset=utf-8', 'Date': 'Wed, 24 Nov 2021 13:52:14 GMT', 'Server': 'nginx/1.10.3 (Ubuntu)', 'X-Ms-Request-Id': '44c6cd42-9dc1-46ce-b007-78b7d0844908', 'X-Ms-Run-Function-Failed': 'True'}\nContent: b\"Object of type 'ndarray' is not JSON serializable\""
#     }
# }

# %%
service.get_logs()
# Out:
# '[0.6274510025978088], [0.6745098233222961], [0.729411780834198], [0.729411780834198], [0.729411780834198], [0.7137255072593689], [0.6901960968971252], [0.6784313917160034], [0.6627451181411743], [0.615686297416687], [0.5647059082984924], [0.5372549295425415], [0.5215686559677124], [0.5098039507865906], [0.501960813999176], [0.4901960790157318], [0.4901960790157318], [0.48627451062202454], [0.48627451062202454], [0.47843137383461], [0.47843137383461], [0.47058823704719543], [0.47058823704719543], [0.46666666865348816], [0.4627451002597809], [0.4627451002597809], [0.45490196347236633], [0.4431372582